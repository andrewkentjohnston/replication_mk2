# %% [markdown]
# # The scripts below are for wrangling data within the individual spreadsheets for each LDC for years 1999 and 2001.

# %% [markdown]
# Create a new variable "emne" that is True if name of country isn't found in list of developed economies.
# List of Developed Economies taken from UNCTAD LDC Report 1999 found here: https://unctad.org/system/files/official-document/ldc1999_en.pdf

# %%
import os
import pandas as pd

# Load the list of developed economies from the Excel file
developed_economies_file = "./data/raw_data_sources/developed_economies_list.xlsx"
developed_economies_df = pd.read_excel(developed_economies_file, sheet_name="Sheet1")
developed_economies = set(developed_economies_df["country_name"].tolist())


# Function to process a single CSV file
def process_csv(file_path):
    df = pd.read_csv(file_path)
    df["emne"] = df["home_economy"].apply(
        lambda x: False if x in developed_economies else True
    )
    df.to_csv(file_path, index=False)


# Directories to process
directories = ["./data/country_spreadsheets/1999", "./data/country_spreadsheets/2001"]

# Process each CSV file in the directories
for directory in directories:
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            process_csv(file_path)

print("Processing complete.")
# Out:
# Processing complete.

# %% [markdown]
# Create new variable "nat_res_ind" based on coding in nat_resource_industries.csv file.

# %%
import pandas as pd
import os

# Define the paths to the directories containing the CSV files
dir1 = "./data/country_spreadsheets/1999"  # Update this path as needed
dir2 = "./data/country_spreadsheets/2001"  # Update this path as needed

# Read the natural resource industries into a set with boolean conversion
nat_res_ind_path = "./data/supplementary_data/nat_resource_industries.csv"
nat_res_ind_df = pd.read_csv(nat_res_ind_path)
nat_res_ind_df["nat_resource"] = (
    nat_res_ind_df["nat_resource"].astype(str).str.lower() == "true"
)
nat_res_industries = set(
    nat_res_ind_df[nat_res_ind_df["nat_resource"]]["industry"].str.strip()
)


# Function to process CSV files with filtering for nat_resource == True
def process_csv_files(directory, nat_res_industries):
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            df["industry"] = df["industry"].astype(str).str.strip()
            df["nat_res_ind"] = df["industry"].apply(lambda x: x in nat_res_industries)
            df.to_csv(file_path, index=False)


# Process the directories with the correct reference to nat_res_industries
process_csv_files(dir1, nat_res_industries)
process_csv_files(dir2, nat_res_industries)

# %% [markdown]
# Create new variable former_col_power based on coding in colonial_powers.csv

# %%
import os
import pandas as pd

# Define the paths to the directories containing the CSV files
dir1999 = "./data/country_spreadsheets/1999"  # Replace with the actual path to the 1999 directory
dir2001 = "./data/country_spreadsheets/2001"  # Replace with the actual path to the 2001 directory

# Read the colonial rulers list into a dictionary
colonial_rulers_path = "./data/supplementary_data/colonial_rulers_list.csv"
colonial_rulers_df = pd.read_csv(colonial_rulers_path)
colonial_rulers_dict = colonial_rulers_df.set_index("country")[
    "colonial_rulers"
].to_dict()


# Function to process CSV files and add former_col_power column
def process_csv_files(directory, colonial_rulers_dict):
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            # Extract the country name by removing the last underscore and year
            country = "_".join(filename.split("_")[:-1])
            former_colonial_power = colonial_rulers_dict.get(country, None)
            if former_colonial_power:
                file_path = os.path.join(directory, filename)
                df = pd.read_csv(file_path)
                df["former_col_power"] = df["home_economy"].apply(
                    lambda x: x == former_colonial_power
                )
                df.to_csv(file_path, index=False)


# Process the directories
process_csv_files(dir1999, colonial_rulers_dict)
process_csv_files(dir2001, colonial_rulers_dict)

print("Processed files and added former_col_power column.")
# Out:
# Processed files and added former_col_power column.

# %% [markdown]
# Create new variable neighbouring_country for based on coding in neighbouring_country spreadsheet.

# %%
import os
import pandas as pd

# Define the paths to the directories containing the CSV files
dir1999 = "./data/country_spreadsheets/1999"  # Replace with the actual path to the 1999 directory
dir2001 = "./data/country_spreadsheets/2001"  # Replace with the actual path to the 2001 directory

# Read the bordering countries list into a dictionary
bordering_countries_path = "./data/supplementary_data/bordering_countries.csv"
bordering_countries_df = pd.read_csv(bordering_countries_path)

# Print the first few rows of bordering_countries_df for debugging
print("Bordering Countries DataFrame:")
print(bordering_countries_df.head())

# Create a dictionary where the key is the country and the value is a list of bordering countries
bordering_countries_dict = {}
for _, row in bordering_countries_df.iterrows():
    country = row["country"]
    borders = row["bordering_countries"]
    if isinstance(borders, str):  # Ensure borders is a string
        bordering_countries_dict[country] = [
            border.replace(" ", "_").lower() for border in borders.split(", ")
        ]

# Print the bordering_countries_dict for debugging
print("\nBordering Countries Dictionary:")
for country, borders in bordering_countries_dict.items():
    print(f"{country}: {borders}")


# Function to convert Title Case to snake_case
def to_snake_case(s):
    return s.lower().replace(" ", "_")


# Function to process CSV files and add bordering_country column
def process_csv_files(directory, bordering_countries_dict):
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            # Extract the country name by removing the last underscore and year
            country = "_".join(filename.split("_")[:-1])
            bordering_countries = bordering_countries_dict.get(country, [])

            # Print the country and its bordering countries for debugging
            print(f"\nProcessing file: {filename}")
            print(f"Country: {country}")
            print(f"Bordering countries: {bordering_countries}")

            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            df["bordering_country"] = df["home_economy"].apply(
                lambda x: to_snake_case(x) in bordering_countries
            )

            # Print a sample of the DataFrame for debugging
            print(df[["home_economy", "bordering_country"]].head())

            df.to_csv(file_path, index=False)


# Process the directories
process_csv_files(dir1999, bordering_countries_dict)
process_csv_files(dir2001, bordering_countries_dict)

print("Processed files and added bordering_country column.")
# Out:
# Bordering Countries DataFrame:
#        country                                bordering_countries
# 0  afghanistan  china, iran, pakistan, tajikistan, turkmenista...
# 1       angola  democratic_republic_of_congo, congo, namibia, ...
# 2   bangladesh                                       burma, india
# 3        benin                 burkina_faso, niger, nigeria, togo
# 4       bhutan                                       china, india
#
# Bordering Countries Dictionary:
# afghanistan: ['china', 'iran', 'pakistan', 'tajikistan', 'turkmenistan', 'uzbekistan']
# angola: ['democratic_republic_of_congo', 'congo', 'namibia', 'zambia']
# bangladesh: ['burma', 'india']
# benin: ['burkina_faso', 'niger', 'nigeria', 'togo']
# bhutan: ['china', 'india']
# burkina_faso: ['benin', "cote_d'ivoire", 'ghana', 'mali', 'niger', 'togo']
# burundi: ['democratic_republic_of_congo', 'rwanda', 'tanzania']
# cambodia: ['laos', 'thailand', 'vietnam']
# central_african_republic: ['cameroon', 'chad', 'democratic_republic_of_congo', 'congo', 'sudan']
# chad: ['cameroon', 'central_african_republic', 'libya', 'niger', 'nigeria', 'sudan']
# democratic_republic_of_congo: ['angola', 'burundi', 'central_african_republic', 'congo', 'rwanda', 'sudan', 'tanzania', 'uganda', 'zambia']
# djibouti: ['eritrea', 'ethiopia', 'somalia']
# equatorial_guinea: ['cameroon', 'gabon']
# eritrea: ['djibouti', 'ethiopia', 'sudan']
# ethiopia: ['djibouti', 'eritrea', 'kenya', 'somalia', 'sudan']
# gambia: ['senegal']
# guinea: ["cote_d'ivoire", 'guinea_bissau', 'liberia', 'mali', 'senegal', 'sierra_leone']
# guinea_bissau: ['guinea', 'senegal']
# haiti: ['dominican_republic']
# laos: ['burma', 'cambodia', 'china', 'thailand', 'vietnam']
# lesotho: ['south_africa']
# liberia: ['guinea', "cote_d'ivoire", 'sierra_leone']
# malawi: ['mozambique', 'tanzania', 'zambia']
# mali: ['algeria', 'burkina_faso', 'guinea']
# mauritania: ['algeria', 'mali', 'senegal', 'western_sahara']
# mozambique: ['malawi', 'south_africa', 'swaziland', 'tanzania', 'zambia', 'zimbabwe']
# myanmar: ['bangladesh', 'china', 'india', 'laos', 'thailand']
# nepal: ['china', 'india']
# niger: ['algeria', 'benin', 'burkina_faso', 'chad', 'libya', 'mali', 'nigeria']
# rwanda: ['burundi', 'democratic_republic_of_congo', 'tanzania', 'uganda']
# senegal: ['gambia', 'guinea', 'guinea_bissau', 'mali', 'mauritania']
# sierra_leone: ['guinea', 'liberia']
# somalia: ['djibouti', 'ethiopia', 'kenya']
# sudan: ['central_african_republic', 'chad', 'democratic_republic_of_congo', 'egypt', 'eritrea', 'ethiopia', 'kenya', 'libya', 'uganda']
# tanzania: ['burundi', 'democratic_republic_of_congo', 'kenya', 'malawi', 'mozambique', 'rwanda', 'uganda', 'zambia']
# togo: ['benin', 'burkina_faso', 'ghana']
# uganda: ['democratic_republic_of_congo', 'kenya', 'rwanda', 'sudan', 'tanzania']
# yemen: ['oman', 'saudi_arabia']
# zambia: ['angola', 'democratic_republic_of_congo', 'malawi', 'mozambique', 'namibia', 'tanzania', 'zimbabwe']
#
# Processing file: samoa_1999.csv
# Country: samoa
# Bordering countries: []
#   home_economy  bordering_country
# 0    Australia              False
# 1        Japan              False
# 2    Australia              False
# 3    Australia              False
# 4         Fiji              False
#
# Processing file: afghanistan_1999.csv
# Country: afghanistan
# Bordering countries: ['china', 'iran', 'pakistan', 'tajikistan', 'turkmenistan', 'uzbekistan']
#   home_economy  bordering_country
# 0      Hungary              False
# 1       Mexico              False
# 2      Hungary              False
#
# Processing file: niger_1999.csv
# Country: niger
# Bordering countries: ['algeria', 'benin', 'burkina_faso', 'chad', 'libya', 'mali', 'nigeria']
#   home_economy  bordering_country
# 0        Japan              False
# 1       France              False
# 2       France              False
# 3   Luxembourg              False
# 4       France              False
#
# Processing file: uganda_1999.csv
# Country: uganda
# Bordering countries: ['democratic_republic_of_congo', 'kenya', 'rwanda', 'sudan', 'tanzania']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1           India              False
# 2     Switzerland              False
# 3       Hong Kong              False
# 4           Kenya               True
#
# Processing file: madagascar_1999.csv
# Country: madagascar
# Bordering countries: []
#   home_economy  bordering_country
# 0  Netherlands              False
# 1       France              False
# 2      Ireland              False
# 3      Germany              False
# 4        Japan              False
#
# Processing file: somalia_1999.csv
# Country: somalia
# Bordering countries: ['djibouti', 'ethiopia', 'kenya']
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: mozambique_1999.csv
# Country: mozambique
# Bordering countries: ['malawi', 'south_africa', 'swaziland', 'tanzania', 'zambia', 'zimbabwe']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1  United Kingdom              False
# 2    South Africa               True
# 3        Portugal              False
# 4           Japan              False
#
# Processing file: democratic_republic_of_congo_1999.csv
# Country: democratic_republic_of_congo
# Bordering countries: ['angola', 'burundi', 'central_african_republic', 'congo', 'rwanda', 'sudan', 'tanzania', 'uganda', 'zambia']
#      home_economy  bordering_country
# 0         Belgium              False
# 1          France              False
# 2          France              False
# 3  United Kingdom              False
# 4           Japan              False
#
# Processing file: benin_1999.csv
# Country: benin
# Bordering countries: ['burkina_faso', 'niger', 'nigeria', 'togo']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1          France              False
# 2          France              False
# 3          France              False
# 4          France              False
#
# Processing file: haiti_1999.csv
# Country: haiti
# Bordering countries: ['dominican_republic']
#     home_economy  bordering_country
# 0  United States              False
# 1         France              False
# 2  United States              False
# 3  United States              False
# 4  United States              False
#
# Processing file: bhutan_1999.csv
# Country: bhutan
# Bordering countries: ['china', 'india']
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: burundi_1999.csv
# Country: burundi
# Bordering countries: ['democratic_republic_of_congo', 'rwanda', 'tanzania']
#   home_economy  bordering_country
# 0  Netherlands              False
# 1       France              False
# 2      Belgium              False
#
# Processing file: comoros_1999.csv
# Country: comoros
# Bordering countries: []
#   home_economy  bordering_country
# 0       France              False
#
# Processing file: bangladesh_1999.csv
# Country: bangladesh
# Bordering countries: ['burma', 'india']
#      home_economy  bordering_country
# 0          France              False
# 1  United Kingdom              False
# 2           Japan              False
# 3     Netherlands              False
# 4   United States              False
#
# Processing file: sao_tome_and_principe_1999.csv
# Country: sao_tome_and_principe
# Bordering countries: []
#   home_economy  bordering_country
# 0     Portugal              False
#
# Processing file: zambia_1999.csv
# Country: zambia
# Bordering countries: ['angola', 'democratic_republic_of_congo', 'malawi', 'mozambique', 'namibia', 'tanzania', 'zimbabwe']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1           India              False
# 2   United States              False
# 3  United Kingdom              False
# 4  United Kingdom              False
#
# Processing file: sierra_leone_1999.csv
# Country: sierra_leone
# Bordering countries: ['guinea', 'liberia']
#      home_economy  bordering_country
# 0  United Kingdom              False
#
# Processing file: nepal_1999.csv
# Country: nepal
# Bordering countries: ['china', 'india']
#   home_economy  bordering_country
# 0       France              False
# 1        Japan              False
# 2    Australia              False
# 3        Japan              False
# 4        Japan              False
#
# Processing file: malawi_1999.csv
# Country: malawi
# Bordering countries: ['mozambique', 'tanzania', 'zambia']
#   home_economy  bordering_country
# 0      Denmark              False
#
# Processing file: yemen_1999.csv
# Country: yemen
# Bordering countries: ['oman', 'saudi_arabia']
#     home_economy  bordering_country
# 0         Canada              False
# 1    Netherlands              False
# 2         France              False
# 3  United States              False
#
# Processing file: sudan_1999.csv
# Country: sudan
# Bordering countries: ['central_african_republic', 'chad', 'democratic_republic_of_congo', 'egypt', 'eritrea', 'ethiopia', 'kenya', 'libya', 'uganda']
#     home_economy  bordering_country
# 0    Netherlands              False
# 1    Netherlands              False
# 2  United States              False
#
# Processing file: mauritania_1999.csv
# Country: mauritania
# Bordering countries: ['algeria', 'mali', 'senegal', 'western_sahara']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
#
# Processing file: central_african_republic_1999.csv
# Country: central_african_republic
# Bordering countries: ['cameroon', 'chad', 'democratic_republic_of_congo', 'congo', 'sudan']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2       France              False
# 3       France              False
#
# Processing file: angola_1999.csv
# Country: angola
# Bordering countries: ['democratic_republic_of_congo', 'congo', 'namibia', 'zambia']
#      home_economy  bordering_country
# 0          Brazil              False
# 1   United States              False
# 2  United Kingdom              False
# 3        Portugal              False
# 4          France              False
#
# Processing file: lesotho_1999.csv
# Country: lesotho
# Bordering countries: ['south_africa']
#      home_economy  bordering_country
# 0          France              False
# 1  United Kingdom              False
#
# Processing file: senegal_1999.csv
# Country: senegal
# Bordering countries: ['gambia', 'guinea', 'guinea_bissau', 'mali', 'mauritania']
#     home_economy  bordering_country
# 0         France              False
# 1    Switzerland              False
# 2  United States              False
# 3         France              False
# 4         France              False
#
# Processing file: mali_1999.csv
# Country: mali
# Bordering countries: ['algeria', 'burkina_faso', 'guinea']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2       France              False
# 3       France              False
#
# Processing file: chad_1999.csv
# Country: chad
# Bordering countries: ['cameroon', 'central_african_republic', 'libya', 'niger', 'nigeria', 'sudan']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2       France              False
#
# Processing file: kiribati_1999.csv
# Country: kiribati
# Bordering countries: []
#   home_economy  bordering_country
# 0    Australia              False
#
# Processing file: liberia_1999.csv
# Country: liberia
# Bordering countries: ['guinea', "cote_d'ivoire", 'sierra_leone']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2        Japan              False
# 3        Japan              False
# 4        Japan              False
#
# Processing file: cambodia_1999.csv
# Country: cambodia
# Bordering countries: ['laos', 'thailand', 'vietnam']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
#
# Processing file: gambia_1999.csv
# Country: gambia
# Bordering countries: ['senegal']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1     Switzerland              False
# 2  United Kingdom              False
# 3         Ireland              False
# 4           Italy              False
#
# Processing file: togo_1999.csv
# Country: togo
# Bordering countries: ['benin', 'burkina_faso', 'ghana']
#   home_economy  bordering_country
# 0  Netherlands              False
# 1       France              False
# 2       France              False
# 3       France              False
# 4        India              False
#
# Processing file: equatorial_guinea_1999.csv
# Country: equatorial_guinea
# Bordering countries: ['cameroon', 'gabon']
#     home_economy  bordering_country
# 0  United States              False
#
# Processing file: burkina_faso_1999.csv
# Country: burkina_faso
# Bordering countries: ['benin', "cote_d'ivoire", 'ghana', 'mali', 'niger', 'togo']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2       France              False
# 3        India              False
# 4       France              False
#
# Processing file: cape_verde_1999.csv
# Country: cape_verde
# Bordering countries: []
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: myanmar_1999.csv
# Country: myanmar
# Bordering countries: ['bangladesh', 'china', 'india', 'laos', 'thailand']
#   home_economy  bordering_country
# 0        Japan              False
# 1    Singapore              False
# 2  South Korea              False
# 3        Japan              False
# 4    Singapore              False
#
# Processing file: guinea_1999.csv
# Country: guinea
# Bordering countries: ["cote_d'ivoire", 'guinea_bissau', 'liberia', 'mali', 'senegal', 'sierra_leone']
#   home_economy  bordering_country
# 0   Luxembourg              False
# 1  Netherlands              False
# 2     Malaysia              False
# 3       France              False
# 4       France              False
#
# Processing file: solomon_islands_1999.csv
# Country: solomon_islands
# Bordering countries: []
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1       Australia              False
# 2            Fiji              False
# 3           Japan              False
# 4  United Kingdom              False
#
# Processing file: tuvalu_1999.csv
# Country: tuvalu
# Bordering countries: []
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: rwanda_1999.csv
# Country: rwanda
# Bordering countries: ['burundi', 'democratic_republic_of_congo', 'tanzania', 'uganda']
#      home_economy  bordering_country
# 0     Netherlands              False
# 1  United Kingdom              False
#
# Processing file: guinea_bissau_1999.csv
# Country: guinea_bissau
# Bordering countries: ['guinea', 'senegal']
#   home_economy  bordering_country
# 0     Portugal              False
#
# Processing file: ethiopia_1999.csv
# Country: ethiopia
# Bordering countries: ['djibouti', 'eritrea', 'kenya', 'somalia', 'sudan']
#      home_economy  bordering_country
# 0           Japan              False
# 1         Germany              False
# 2         Germany              False
# 3  United Kingdom              False
# 4           Japan              False
#
# Processing file: maldives_1999.csv
# Country: maldives
# Bordering countries: []
#   home_economy  bordering_country
# 0        Japan              False
# 1        India              False
# 2    Singapore              False
#
# Processing file: vanuatu_1999.csv
# Country: vanuatu
# Bordering countries: []
#   home_economy  bordering_country
# 0    Hong Kong              False
# 1    Australia              False
# 2    Hong Kong              False
# 3        Japan              False
# 4        Japan              False
#
# Processing file: eritrea_1999.csv
# Country: eritrea
# Bordering countries: ['djibouti', 'ethiopia', 'sudan']
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: tanzania_1999.csv
# Country: tanzania
# Bordering countries: ['burundi', 'democratic_republic_of_congo', 'kenya', 'malawi', 'mozambique', 'rwanda', 'uganda', 'zambia']
#   home_economy  bordering_country
# 0        Ghana              False
# 1   Luxembourg              False
# 2        Kenya               True
# 3      Germany              False
# 4        Kenya               True
#
# Processing file: laos_1999.csv
# Country: laos
# Bordering countries: ['burma', 'cambodia', 'china', 'thailand', 'vietnam']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2        Japan              False
# 3        Japan              False
#
# Processing file: djibouti_1999.csv
# Country: djibouti
# Bordering countries: ['eritrea', 'ethiopia', 'somalia']
#    home_economy  bordering_country
# 0        France              False
# 1   Netherlands              False
# 2  Saudi Arabia              False
# 3   Switzerland              False
# 4   Switzerland              False
#
# Processing file: yemen_2001.csv
# Country: yemen
# Bordering countries: ['oman', 'saudi_arabia']
#     home_economy  bordering_country
# 0         Canada              False
# 1    Netherlands              False
# 2         France              False
# 3  United States              False
# 4    Netherlands              False
#
# Processing file: sudan_2001.csv
# Country: sudan
# Bordering countries: ['central_african_republic', 'chad', 'democratic_republic_of_congo', 'egypt', 'eritrea', 'ethiopia', 'kenya', 'libya', 'uganda']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1     Netherlands              False
# 2     Netherlands              False
# 3   United States              False
# 4     South Korea              False
#
# Processing file: mauritania_2001.csv
# Country: mauritania
# Bordering countries: ['algeria', 'mali', 'senegal', 'western_sahara']
#   home_economy  bordering_country
# 0       France              False
# 1      Morocco              False
#
# Processing file: angola_2001.csv
# Country: angola
# Bordering countries: ['democratic_republic_of_congo', 'congo', 'namibia', 'zambia']
#      home_economy  bordering_country
# 0          Brazil              False
# 1          France              False
# 2  United Kingdom              False
# 3   United States              False
# 4        Portugal              False
#
# Processing file: central_african_republic_2001.csv
# Country: central_african_republic
# Bordering countries: ['cameroon', 'chad', 'democratic_republic_of_congo', 'congo', 'sudan']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2       France              False
# 3       France              False
# 4       France              False
#
# Processing file: lesotho_2001.csv
# Country: lesotho
# Bordering countries: ['south_africa']
#      home_economy  bordering_country
# 0          France              False
# 1  United Kingdom              False
#
# Processing file: senegal_2001.csv
# Country: senegal
# Bordering countries: ['gambia', 'guinea', 'guinea_bissau', 'mali', 'mauritania']
#     home_economy  bordering_country
# 0         France              False
# 1         France              False
# 2         France              False
# 3    Switzerland              False
# 4  United States              False
#
# Processing file: mali_2001.csv
# Country: mali
# Bordering countries: ['algeria', 'burkina_faso', 'guinea']
#   home_economy  bordering_country
# 0        Malta              False
# 1       France              False
# 2    Australia              False
# 3       France              False
# 4       France              False
#
# Processing file: chad_2001.csv
# Country: chad
# Bordering countries: ['cameroon', 'central_african_republic', 'libya', 'niger', 'nigeria', 'sudan']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2       France              False
# 3       France              False
#
# Processing file: liberia_2001.csv
# Country: liberia
# Bordering countries: ['guinea', "cote_d'ivoire", 'sierra_leone']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2        Japan              False
# 3        Japan              False
# 4        Japan              False
#
# Processing file: kiribati_2001.csv
# Country: kiribati
# Bordering countries: []
#   home_economy  bordering_country
# 0    Australia              False
#
# Processing file: uganda_2001.csv
# Country: uganda
# Bordering countries: ['democratic_republic_of_congo', 'kenya', 'rwanda', 'sudan', 'tanzania']
#      home_economy  bordering_country
# 0    South Africa              False
# 1  United Kingdom              False
# 2  United Kingdom              False
# 3           India              False
# 4     Switzerland              False
#
# Processing file: samoa_2001.csv
# Country: samoa
# Bordering countries: []
#   home_economy  bordering_country
# 0        Japan              False
# 1    Australia              False
# 2        Japan              False
# 3    Australia              False
# 4    Australia              False
#
# Processing file: niger_2001.csv
# Country: niger
# Bordering countries: ['algeria', 'benin', 'burkina_faso', 'chad', 'libya', 'mali', 'nigeria']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2       France              False
# 3       France              False
# 4       France              False
#
# Processing file: afghanistan_2001.csv
# Country: afghanistan
# Bordering countries: ['china', 'iran', 'pakistan', 'tajikistan', 'turkmenistan', 'uzbekistan']
#   home_economy  bordering_country
# 0      Hungary              False
# 1       Mexico              False
# 2      Hungary              False
#
# Processing file: mozambique_2001.csv
# Country: mozambique
# Bordering countries: ['malawi', 'south_africa', 'swaziland', 'tanzania', 'zambia', 'zimbabwe']
#      home_economy  bordering_country
# 0   United States              False
# 1        Portugal              False
# 2  United Kingdom              False
# 3    South Africa               True
# 4        Portugal              False
#
# Processing file: somalia_2001.csv
# Country: somalia
# Bordering countries: ['djibouti', 'ethiopia', 'kenya']
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: madagascar_2001.csv
# Country: madagascar
# Bordering countries: []
#   home_economy  bordering_country
# 0  Netherlands              False
# 1       France              False
# 2       France              False
# 3    Mauritius              False
# 4      Ireland              False
#
# Processing file: democratic_republic_of_congo_2001.csv
# Country: democratic_republic_of_congo
# Bordering countries: ['angola', 'burundi', 'central_african_republic', 'congo', 'rwanda', 'sudan', 'tanzania', 'uganda', 'zambia']
#      home_economy  bordering_country
# 0          France              False
# 1         Belgium              False
# 2           Congo               True
# 3  United Kingdom              False
# 4           Japan              False
#
# Processing file: benin_2001.csv
# Country: benin
# Bordering countries: ['burkina_faso', 'niger', 'nigeria', 'togo']
#     home_economy  bordering_country
# 0    Netherlands              False
# 1  United States              False
# 2         France              False
# 3         France              False
# 4         France              False
#
# Processing file: burundi_2001.csv
# Country: burundi
# Bordering countries: ['democratic_republic_of_congo', 'rwanda', 'tanzania']
#   home_economy  bordering_country
# 0  Netherlands              False
# 1       France              False
# 2      Belgium              False
#
# Processing file: bhutan_2001.csv
# Country: bhutan
# Bordering countries: ['china', 'india']
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: comoros_2001.csv
# Country: comoros
# Bordering countries: []
#   home_economy  bordering_country
# 0       France              False
#
# Processing file: haiti_2001.csv
# Country: haiti
# Bordering countries: ['dominican_republic']
#     home_economy  bordering_country
# 0  United States              False
# 1  United States              False
# 2  United States              False
# 3         France              False
# 4  United States              False
#
# Processing file: sao_tome_and_principe_2001.csv
# Country: sao_tome_and_principe
# Bordering countries: []
#   home_economy  bordering_country
# 0     Portugal              False
#
# Processing file: bangladesh_2001.csv
# Country: bangladesh
# Bordering countries: ['burma', 'india']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1           Japan              False
# 2     Netherlands              False
# 3   United States              False
# 4   United States              False
#
# Processing file: zambia_2001.csv
# Country: zambia
# Bordering countries: ['angola', 'democratic_republic_of_congo', 'malawi', 'mozambique', 'namibia', 'tanzania', 'zimbabwe']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1           India              False
# 2   United States              False
# 3  United Kingdom              False
# 4  United Kingdom              False
#
# Processing file: sierra_leone_2001.csv
# Country: sierra_leone
# Bordering countries: ['guinea', 'liberia']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1  United Kingdom              False
# 2  United Kingdom              False
#
# Processing file: malawi_2001.csv
# Country: malawi
# Bordering countries: ['mozambique', 'tanzania', 'zambia']
#   home_economy  bordering_country
# 0      Denmark              False
#
# Processing file: nepal_2001.csv
# Country: nepal
# Bordering countries: ['china', 'india']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2        Japan              False
# 3        Japan              False
# 4       France              False
#
# Processing file: ethiopia_2001.csv
# Country: ethiopia
# Bordering countries: ['djibouti', 'eritrea', 'kenya', 'somalia', 'sudan']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1           Japan              False
# 2         Germany              False
# 3   United States              False
# 4         Germany              False
#
# Processing file: maldives_2001.csv
# Country: maldives
# Bordering countries: []
#   home_economy  bordering_country
# 0        Japan              False
# 1    Singapore              False
# 2        India              False
#
# Processing file: vanuatu_2001.csv
# Country: vanuatu
# Bordering countries: []
#   home_economy  bordering_country
# 0    Hong Kong              False
# 1        Japan              False
# 2        Japan              False
# 3    Australia              False
# 4    Australia              False
#
# Processing file: eritrea_2001.csv
# Country: eritrea
# Bordering countries: ['djibouti', 'ethiopia', 'sudan']
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: tanzania_2001.csv
# Country: tanzania
# Bordering countries: ['burundi', 'democratic_republic_of_congo', 'kenya', 'malawi', 'mozambique', 'rwanda', 'uganda', 'zambia']
#     home_economy  bordering_country
# 0          Ghana              False
# 1  United States              False
# 2     Luxembourg              False
# 3          Japan              False
# 4          Kenya               True
#
# Processing file: laos_2001.csv
# Country: laos
# Bordering countries: ['burma', 'cambodia', 'china', 'thailand', 'vietnam']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
#
# Processing file: djibouti_2001.csv
# Country: djibouti
# Bordering countries: ['eritrea', 'ethiopia', 'somalia']
#    home_economy  bordering_country
# 0   Switzerland              False
# 1        France              False
# 2   Netherlands              False
# 3  Saudi Arabia              False
# 4   Switzerland              False
#
# Processing file: togo_2001.csv
# Country: togo
# Bordering countries: ['benin', 'burkina_faso', 'ghana']
#   home_economy  bordering_country
# 0      Germany              False
# 1  Netherlands              False
# 2       France              False
# 3       France              False
# 4       France              False
#
# Processing file: cambodia_2001.csv
# Country: cambodia
# Bordering countries: ['laos', 'thailand', 'vietnam']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2        Japan              False
#
# Processing file: gambia_2001.csv
# Country: gambia
# Bordering countries: ['senegal']
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1          France              False
# 2     Switzerland              False
# 3  United Kingdom              False
# 4         Ireland              False
#
# Processing file: equatorial_guinea_2001.csv
# Country: equatorial_guinea
# Bordering countries: ['cameroon', 'gabon']
#     home_economy  bordering_country
# 0  United States              False
# 1      Hong Kong              False
#
# Processing file: burkina_faso_2001.csv
# Country: burkina_faso
# Bordering countries: ['benin', "cote_d'ivoire", 'ghana', 'mali', 'niger', 'togo']
#   home_economy  bordering_country
# 0       France              False
# 1       France              False
# 2        India              False
# 3      Senegal              False
# 4       France              False
#
# Processing file: cape_verde_2001.csv
# Country: cape_verde
# Bordering countries: []
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: myanmar_2001.csv
# Country: myanmar
# Bordering countries: ['bangladesh', 'china', 'india', 'laos', 'thailand']
#   home_economy  bordering_country
# 0        Japan              False
# 1        Japan              False
# 2        Japan              False
# 3        Japan              False
# 4        Japan              False
#
# Processing file: solomon_islands_2001.csv
# Country: solomon_islands
# Bordering countries: []
#      home_economy  bordering_country
# 0  United Kingdom              False
# 1       Australia              False
# 2            Fiji              False
# 3           Japan              False
# 4        Malaysia              False
#
# Processing file: guinea_2001.csv
# Country: guinea
# Bordering countries: ["cote_d'ivoire", 'guinea_bissau', 'liberia', 'mali', 'senegal', 'sierra_leone']
#   home_economy  bordering_country
# 0  Netherlands              False
# 1   Luxembourg              False
# 2  Netherlands              False
# 3     Malaysia              False
# 4       France              False
#
# Processing file: tuvalu_2001.csv
# Country: tuvalu
# Bordering countries: []
# Empty DataFrame
# Columns: [home_economy, bordering_country]
# Index: []
#
# Processing file: rwanda_2001.csv
# Country: rwanda
# Bordering countries: ['burundi', 'democratic_republic_of_congo', 'tanzania', 'uganda']
#      home_economy  bordering_country
# 0     Netherlands              False
# 1  United Kingdom              False
#
# Processing file: guinea_bissau_2001.csv
# Country: guinea_bissau
# Bordering countries: ['guinea', 'senegal']
#   home_economy  bordering_country
# 0     Portugal              False
# Processed files and added bordering_country column.

# %% [markdown]
# # Working with master spreadsheets for 1999 and 2001

# %% [markdown]
# Create master spreadsheet for 1999

# %%
import os
import pandas as pd

# Directory where the CSV files are located
directory = "./data/country_spreadsheets/1999"  # Change this to your directory path

# List of all CSV files in the directory
csv_files = [f for f in os.listdir(directory) if f.endswith(".csv")]

# List to store the results
results = []
missing_former_col_power_files = []


# Function to calculate the proportions
def calculate_proportions(df, col):
    total_count = len(df)
    if total_count == 0:
        return None
    mne_count = df[df["emne"] == True].shape[0]
    return mne_count / total_count


# Process each CSV file
for file in csv_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)

    # Extract the country name by splitting the filename at the last underscore
    country = "_".join(file.split("_")[:-1])

    # Calculate the required proportions
    prop_emnes = calculate_proportions(df, "emne")

    if "nat_res_ind" in df.columns:
        prop_emnes_excl_nat_res = calculate_proportions(
            df[df["nat_res_ind"] == False], "emne"
        )
    else:
        prop_emnes_excl_nat_res = prop_emnes

    if "former_col_power" in df.columns:
        prop_emnes_excl_former_col_power = calculate_proportions(
            df[df["former_col_power"] == False], "emne"
        )
    else:
        prop_emnes_excl_former_col_power = prop_emnes
        missing_former_col_power_files.append(file)

    if "bordering_country" in df.columns:
        prop_emnes_excl_neighbors = calculate_proportions(
            df[df["bordering_country"] == False], "emne"
        )
    else:
        prop_emnes_excl_neighbors = prop_emnes

    # Check if there are zero companies
    zero_mnes = len(df) == 0

    # Check if there are zero companies excluding natural resource companies
    zero_mnes_excl_nat_res = (
        len(df[df["nat_res_ind"] == False]) == 0
        if "nat_res_ind" in df.columns
        else zero_mnes
    )

    # Check if there are zero companies excluding former colonial powers
    zero_mnes_excl_former_col_power = (
        len(df[df["former_col_power"] == False]) == 0
        if "former_col_power" in df.columns
        else zero_mnes
    )

    # Check if there are zero companies excluding neighboring countries
    zero_mnes_excl_neighbors = (
        len(df[df["bordering_country"] == False]) == 0
        if "bordering_country" in df.columns
        else zero_mnes
    )

    # Append the results
    results.append(
        {
            "country": country,
            "prop_emnes": prop_emnes,
            "prop_emnes_excl_nat_res": prop_emnes_excl_nat_res,
            "prop_emnes_excl_former_col_power": prop_emnes_excl_former_col_power,
            "prop_emnes_excl_neighbors": prop_emnes_excl_neighbors,
            "zero_mnes": zero_mnes,
            "zero_mnes_excl_nat_res": zero_mnes_excl_nat_res,
            "zero_mnes_excl_former_col_power": zero_mnes_excl_former_col_power,
            "zero_mnes_excl_neighbors": zero_mnes_excl_neighbors,
        }
    )

# Create a DataFrame from the results
master_df = pd.DataFrame(results)

# Save the master DataFrame to a CSV file
output_path = os.path.join(directory, "ldcs_1999_master.csv")
master_df.to_csv(output_path, index=False)

print(f"Master CSV file created at: {output_path}")

# Print the list of files missing the former_col_power column
if missing_former_col_power_files:
    print("The following files were missing the 'former_col_power' column:")
    for missing_file in missing_former_col_power_files:
        print(missing_file)
else:
    print("No files were missing the 'former_col_power' column.")

# %% [markdown]
# Create master spreadsheet for 2001

# %%
import os
import pandas as pd

# Directory where the CSV files are located
directory = "./data/country_spreadsheets/2001"  # Change this to your directory path

# List of all CSV files in the directory
csv_files = [f for f in os.listdir(directory) if f.endswith(".csv")]

# List to store the results
results = []
missing_former_col_power_files = []


# Function to calculate the proportions
def calculate_proportions(df, col):
    total_count = len(df)
    if total_count == 0:
        return None
    mne_count = df[df["emne"] == True].shape[0]
    return mne_count / total_count


# Process each CSV file
for file in csv_files:
    file_path = os.path.join(directory, file)
    df = pd.read_csv(file_path)

    # Extract the country name by splitting the filename at the last underscore
    country = "_".join(file.split("_")[:-1])

    # Calculate the required proportions
    prop_emnes = calculate_proportions(df, "emne")

    if "nat_res_ind" in df.columns:
        prop_emnes_excl_nat_res = calculate_proportions(
            df[df["nat_res_ind"] == False], "emne"
        )
    else:
        prop_emnes_excl_nat_res = prop_emnes

    if "former_col_power" in df.columns:
        prop_emnes_excl_former_col_power = calculate_proportions(
            df[df["former_col_power"] == False], "emne"
        )
    else:
        prop_emnes_excl_former_col_power = prop_emnes
        missing_former_col_power_files.append(file)

    if "bordering_country" in df.columns:
        prop_emnes_excl_neighbors = calculate_proportions(
            df[df["bordering_country"] == False], "emne"
        )
    else:
        prop_emnes_excl_neighbors = prop_emnes

    # Check if there are zero companies
    zero_mnes = len(df) == 0

    # Check if there are zero companies excluding natural resource companies
    zero_mnes_excl_nat_res = (
        len(df[df["nat_res_ind"] == False]) == 0
        if "nat_res_ind" in df.columns
        else zero_mnes
    )

    # Check if there are zero companies excluding former colonial powers
    zero_mnes_excl_former_col_power = (
        len(df[df["former_col_power"] == False]) == 0
        if "former_col_power" in df.columns
        else zero_mnes
    )

    # Check if there are zero companies excluding neighboring countries
    zero_mnes_excl_neighbors = (
        len(df[df["bordering_country"] == False]) == 0
        if "bordering_country" in df.columns
        else zero_mnes
    )

    # Append the results
    results.append(
        {
            "country": country,
            "prop_emnes": prop_emnes,
            "prop_emnes_excl_nat_res": prop_emnes_excl_nat_res,
            "prop_emnes_excl_former_col_power": prop_emnes_excl_former_col_power,
            "prop_emnes_excl_neighbors": prop_emnes_excl_neighbors,
            "zero_mnes": zero_mnes,
            "zero_mnes_excl_nat_res": zero_mnes_excl_nat_res,
            "zero_mnes_excl_former_col_power": zero_mnes_excl_former_col_power,
            "zero_mnes_excl_neighbors": zero_mnes_excl_neighbors,
        }
    )

# Create a DataFrame from the results
master_df = pd.DataFrame(results)

# Save the master DataFrame to a CSV file
output_path = os.path.join(directory, "ldcs_2001_master.csv")
master_df.to_csv(output_path, index=False)

print(f"Master CSV file created at: {output_path}")

# Print the list of files missing the former_col_power column
if missing_former_col_power_files:
    print("The following files were missing the 'former_col_power' column:")
    for missing_file in missing_former_col_power_files:
        print(missing_file)
else:
    print("No files were missing the 'former_col_power' column.")
# Out:
# Master CSV file created at: ./data/country_spreadsheets/2001/ldcs_2001_master.csv
# No files were missing the 'former_col_power' column.
